# %%
#1 wap to find the unique employee IDS in a company....
employe_ids=[99,101,102,99,88,10]
unique=set(employe_ids)
print(unique)
# Out:
# {99, 101, 102, 10, 88}

# %%
#2 wap to find the comman departments between two companies.
company_department1=["IT","HR","Finance"]
company_department2=["HR","IT"]
common_department=set(company_department1)&set(company_department2)
print(common_department)
# Out:
# {'HR', 'IT'}

# %%
#3 wap to remove duplicate employee name from a list....
employee_name=["a","b","c","a","d","b"]
duplicate_name=list(set(employee_name))
print(duplicate_name)
# Out:
# ['d', 'a', 'c', 'b']

# %%
#4 wap to find the unique guests invites to party...
guest=["aa","bb","aa","cc","dd","cc"]
unique_guest=set(guest)
print(unique_guest)
# Out:
# {'aa', 'bb', 'cc', 'dd'}

# %%
#5 wap find the common attendance between twp events....
event1_attendance=["a","b","c"]
event2_attendance=["a","d","f"]
common_attendance=set(event1_attendance)&set(event2_attendance)
print(common_attendance)
# Out:
# {'a'}

# %%
#6 wap to remove duplicate event dates from a calender....
event_dates=["1-1-2025","2-2-2025","3-3-2025","2-2-2025"]
date=list(set(event_dates))
print(date)
# Out:
# ['1-1-2025', '2-2-2025', '3-3-2025']

# %%
#7 wap to ffind the unique product codes in inventory...
product_codes=["123AA","789CC","456BB","789CC"]
unique_codes=set(product_codes)
print(unique_codes)
# Out:
# {'789CC', '123AA', '456BB'}

# %%
#8 wap to find the common products between two warehouses.
warehouse1=["product A","product B", "product C"]
warehouse2=["product A", "product D"]
common_product=set(warehouse1)&set(warehouse2)
print(common_product)
# Out:
# {'product A'}

# %%
#9 wap to remove duplicate product names from a catlog......
product1=["product A","product B", "product C","product A","product B", "product C"]
name=list(set(product1))
print(name)
# Out:
# ['product C', 'product B', 'product A']

# %%
#10 wap to find the unique student IDS in a school......
student_ids=["1","2,","11","1"]
ids=set(student_ids)
print(ids)
# Out:
# {'11', '2,', '1'}

# %%
#11 wap to find common courses between two students.......
courses1=["python","AI","DS"]
courses2=["AI","python"]
common_courses=set(courses1)&set(courses2)
print(common_courses)
# Out:
# {'AI', 'python'}

# %%
#12 wap to remove duplicate student names from a roster..
student_name=["a","b","c","a","b"]
duplicate_name=list(set(student_name))
print(duplicate_name)
# Out:
# ['a', 'c', 'b']

# %%
#13 wap to find the unique songs in a playlist..
songs=["A","B","C","C"]
unique_songs=set(songs)
print(unique_songs)
# Out:
# {'C', 'B', 'A'}

# %%
#14 wap to find the common artists from a music collection...
artits1=["aa","bb","cc"]
artits2=["bb","cc","aa"]
common_artits=set(artits1)&set(artits2)
print(common_artits)
# Out:
# {'aa', 'bb', 'cc'}

# %%
#15 wap to remove duplicate albums from a music collection.....
albums=["A","B","C","B"]
duplicate_album=list(set(albums))
print(duplicate_album)
# Out:
# ['C', 'B', 'A']

# %%
#16 wap to find unique movies in watchlist....
movies=["A","B","C","A"]
unique_movies=set(movies)
print(unique_movies)
# Out:
# {'C', 'B', 'A'}

# %%
#17 wap to find common actors between two movies....
movie1=["a","b","c"]
movie2=["a","b","f"]
common_actors=set(movie1)&set(movie2)
print(common_actors)
# Out:
# {'a', 'b'}

# %%
#18 wap to find remove duplicate movie titles from a list....
movie_title=["movie A","movie B","movie A"]
duplicate_titles=list(set(movie_title))
print(duplicate_titles)
# Out:
# ['movie B', 'movie A']

# %%
#19 wap to find unique teams in a league....
teams=["a","b","c","c"]
unique_team=set(teams)
print(unique_team)
# Out:
# {'a', 'c', 'b'}

# %%
#20 wap to find common players between two teams..
team1=["player a","player b","player c"]
team2=["player a","player b","player j"]
common_players=set(team1)&set(team2)
print(common_players)
# Out:
# {'player a', 'player b'}

# %%
#21 wap to remove duplicate player IDS from a roster......
players=["1","2","3","3","1"]
duplicate_ids=list(set(players))
print(duplicate_ids)
# Out:
# ['2', '1', '3']

# %%
#22 wap to find unique authors in libeary...........
authors=["a","b","a","c"]
unique_author=set(authors)
print(unique_author)
# Out:
# {'a', 'c', 'b'}

# %%
#23 wap to find common books between two shelves..
book1=["a","b","c"]
book2=["a","c","b"]
common_book=set(book1)&set(book2)
print(common_book)
# Out:
# {'a', 'c', 'b'}

# %%
#24 waop to remove duplicate book titles from catlog.....
book_title=["a","b","c","c"]
duplicate_titles=list(set(book_title))
print(duplicate_titles)
# Out:
# ['a', 'c', 'b']

# %%
*-
