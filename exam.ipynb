# %%
#1...........
a=int(input("enter no"))
if a%3==0 and a%5!=0:
    print("Divisible by 3 not by 5")
else:
    print("No")
# Out:
# enter no 6
# Divisible by 3 not by 5

# %%
18...........
with open('info.txt','r') as file:
    for line in file:
       print(line)
# Out:
# Welocome to this program python
#
#  data science in AI

# %%
#14.....
container = (3, 2, [40, 20, 30])
print("Before change:", container)
container[2].append(50)
print("After change:", container)
# Out:
# Before change: (3, 2, [40, 20, 30])
# After change: (3, 2, [40, 20, 30, 50])

# %%
#4.........
def block(a):
    print(a)
    if a > 5:
        print(" a is greater than 5")
result = block(10)
print(result)
# Out:
# 10
#  a is greater than 5
# None

# %%
#10......
def replace(a):
    s={}
    result = list(a)
    for i, c in enumerate(a):
        if c in s:
          result[i] = '*'
        s[c] = i
    return ''.join(result)
print(replace("Hiiiilo"))
# Out:
# Hi***lo

# %%
#3..........
a = input("enter no")
b = input("enter no")

if a.isdigit() and b.isdigit(): 
    print(int(a) + int(b))
else: 
    print("INVALID")
# Out:
# enter no 10
# enter no gjh
# INVALID
