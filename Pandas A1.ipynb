# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\om\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\om\anaconda3\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\om\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\om\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\om\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\om\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df=pd.read_csv("Downloads/edtech_student_learning_data.csv")

# %%
df.head(10)
# Out:
#    student_id student_name  gender       city enrollment_date          course  \
# 0        1001    Student_1    Male  Hyderabad      2024-11-25   Generative AI
# 1        1002    Student_2  Female  Hyderabad      2024-09-29         AI & ML
# 2        1003    Student_3    Male       Pune      2024-12-05    Data Science
# 3        1004    Student_4    Male      Delhi      2024-03-09         AI & ML
# 4        1005    Student_5    Male     Mumbai      2024-02-03   Generative AI
# 5        1006    Student_6  Female       Pune      2024-09-18   Generative AI
# 6        1007    Student_7    Male     Mumbai      2024-02-22  Data Analytics
# 7        1008    Student_8    Male    Chennai      2024-07-23    Data Science
# 8        1009    Student_9    Male     Mumbai      2024-05-05         AI & ML
# 9        1010   Student_10  Female      Delhi      2024-08-22  Data Analytics
#
#   batch_type  total_sessions  sessions_attended  avg_quiz_score  \
# 0    Weekday             120                108              59
# 1    Weekday             120                110              57
# 2    Weekday             120                 73              49
# 3    Weekend             120                 71              64
# 4    Weekday             120                101              41
# 5    Weekend             120                 79              64
# 6    Weekend             120                112              93
# 7    Weekend             120                109              72
# 8    Weekend             120                 83              75
# 9    Weekday             120                118              70
#
#    assignment_score  project_score  final_rating  learning_hours  \
# 0                96             66           3.7               6
# 1                93             83           4.5              33
# 2                72             73           3.6               8
# 3                91             81           2.7               5
# 4                55             50           2.1              23
# 5                98             57           2.6              30
# 6                89             94           3.2              29
# 7                77             72           4.3              14
# 8                61             96           2.6              19
# 9                50             89           4.2              26
#
#   placement_status  feedback_score  attendance_pct  salary_offered
# 0           Placed               7           90.00        738963.0
# 1       Not Placed               8           91.67             NaN
# 2           Placed               5           60.83        501904.0
# 3       Not Placed               8           59.17             NaN
# 4           Placed               9           84.17        970105.0
# 5           Placed               6           65.83        305730.0
# 6           Placed               6           93.33        707137.0
# 7           Placed               6           90.83       1053790.0
# 8           Placed               8           69.17        502210.0
# 9       Not Placed               8           98.33             NaN

# %%
df.tail(5)
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 500        1452  Student_452  Female     Mumbai      2024-03-07
# 501        1276  Student_276  Female  Hyderabad      2024-10-15
# 502        1210  Student_210    Male  Bangalore      2024-04-04
# 503        1178  Student_178    Male      Delhi      2024-01-20
# 504        1397  Student_397  Female     Mumbai      2024-05-27
#
#             course batch_type  total_sessions  sessions_attended  \
# 500  Generative AI    Weekday             120                 68
# 501  Generative AI    Weekday             120                 95
# 502        AI & ML    Weekday             120                 75
# 503  Generative AI    Weekday             120                 80
# 504  Generative AI    Weekend             120                101
#
#      avg_quiz_score  assignment_score  project_score  final_rating  \
# 500              84                84             58           2.2
# 501              92                81             91           3.2
# 502              40                84             77           2.4
# 503              97                92             66           4.7
# 504              66                83             66           3.6
#
#      learning_hours placement_status  feedback_score  attendance_pct  \
# 500              19       Not Placed               8           56.67
# 501              16       Not Placed               8           79.17
# 502              19           Placed               5           62.50
# 503              33           Placed               5           66.67
# 504              25           Placed               7           84.17
#
#      salary_offered
# 500             NaN
# 501             NaN
# 502        750043.0
# 503        890611.0
# 504       1003022.0

# %%
df[:]
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 0          1001    Student_1    Male  Hyderabad      2024-11-25
# 1          1002    Student_2  Female  Hyderabad      2024-09-29
# 2          1003    Student_3    Male       Pune      2024-12-05
# 3          1004    Student_4    Male      Delhi      2024-03-09
# 4          1005    Student_5    Male     Mumbai      2024-02-03
# ..          ...          ...     ...        ...             ...
# 500        1452  Student_452  Female     Mumbai      2024-03-07
# 501        1276  Student_276  Female  Hyderabad      2024-10-15
# 502        1210  Student_210    Male  Bangalore      2024-04-04
# 503        1178  Student_178    Male      Delhi      2024-01-20
# 504        1397  Student_397  Female     Mumbai      2024-05-27
#
#             course batch_type  total_sessions  sessions_attended  \
# 0    Generative AI    Weekday             120                108
# 1          AI & ML    Weekday             120                110
# 2     Data Science    Weekday             120                 73
# 3          AI & ML    Weekend             120                 71
# 4    Generative AI    Weekday             120                101
# ..             ...        ...             ...                ...
# 500  Generative AI    Weekday             120                 68
# 501  Generative AI    Weekday             120                 95
# 502        AI & ML    Weekday             120                 75
# 503  Generative AI    Weekday             120                 80
# 504  Generative AI    Weekend             120                101
#
#      avg_quiz_score  assignment_score  project_score  final_rating  \
# 0                59                96             66           3.7
# 1                57                93             83           4.5
# 2                49                72             73           3.6
# 3                64                91             81           2.7
# 4                41                55             50           2.1
# ..              ...               ...            ...           ...
# 500              84                84             58           2.2
# 501              92                81             91           3.2
# 502              40                84             77           2.4
# 503              97                92             66           4.7
# 504              66                83             66           3.6
#
#      learning_hours placement_status  feedback_score  attendance_pct  \
# 0                 6           Placed               7           90.00
# 1                33       Not Placed               8           91.67
# 2                 8           Placed               5           60.83
# 3                 5       Not Placed               8           59.17
# 4                23           Placed               9           84.17
# ..              ...              ...             ...             ...
# 500              19       Not Placed               8           56.67
# 501              16       Not Placed               8           79.17
# 502              19           Placed               5           62.50
# 503              33           Placed               5           66.67
# 504              25           Placed               7           84.17
#
#      salary_offered
# 0          738963.0
# 1               NaN
# 2          501904.0
# 3               NaN
# 4          970105.0
# ..              ...
# 500             NaN
# 501             NaN
# 502        750043.0
# 503        890611.0
# 504       1003022.0
#
# [505 rows x 18 columns]

# %%
df.dtypes
# Out:
# student_id             int64
# student_name          object
# gender                object
# city                  object
# enrollment_date       object
# course                object
# batch_type            object
# total_sessions         int64
# sessions_attended      int64
# avg_quiz_score         int64
# assignment_score       int64
# project_score          int64
# final_rating         float64
# learning_hours         int64
# placement_status      object
# feedback_score         int64
# attendance_pct       float64
# salary_offered       float64
# dtype: object

# %%
df.describe()
# Out:
#         student_id  total_sessions  sessions_attended  avg_quiz_score  \
# count   505.000000           505.0         505.000000      505.000000
# mean   1251.015842           120.0          88.102970       69.601980
# std     144.242011             0.0          17.087232       17.137226
# min    1001.000000           120.0          60.000000       40.000000
# 25%    1127.000000           120.0          73.000000       56.000000
# 50%    1251.000000           120.0          88.000000       69.000000
# 75%    1376.000000           120.0         103.000000       84.000000
# max    1500.000000           120.0         119.000000       99.000000
#
#        assignment_score  project_score  final_rating  learning_hours  \
# count        505.000000     505.000000    477.000000      505.000000
# mean          71.984158      75.287129      3.535220       22.128713
# std           15.777337      14.678794      0.862365        9.924180
# min           45.000000      50.000000      2.000000        5.000000
# 25%           58.000000      62.000000      2.800000       14.000000
# 50%           72.000000      76.000000      3.600000       23.000000
# 75%           86.000000      88.000000      4.300000       31.000000
# max           99.000000      99.000000      5.000000       39.000000
#
#        feedback_score  attendance_pct  salary_offered
# count      505.000000      505.000000    3.360000e+02
# mean         7.041584       73.419149    7.701324e+05
# std          1.370122       14.239418    2.656396e+05
# min          5.000000       50.000000    3.005150e+05
# 25%          6.000000       60.830000    5.442040e+05
# 50%          7.000000       73.330000    7.788115e+05
# 75%          8.000000       85.830000    1.003022e+06
# max          9.000000       99.170000    1.199092e+06

# %%
df.isna().sum()
# Out:
# student_id             0
# student_name           0
# gender                 0
# city                   0
# enrollment_date        0
# course                 0
# batch_type             0
# total_sessions         0
# sessions_attended      0
# avg_quiz_score         0
# assignment_score       0
# project_score          0
# final_rating          28
# learning_hours         0
# placement_status       0
# feedback_score         0
# attendance_pct         0
# salary_offered       169
# dtype: int64

# %%
df['final_rating'].isna().mean()*100
# Out:
# np.float64(5.544554455445545)

# %%
df['final_rating'].isna().sum()
# Out:
# np.int64(28)

# %%
df.duplicated().sum()
# Out:
# np.int64(5)

# %%
df.drop_duplicates()
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 0          1001    Student_1    Male  Hyderabad      2024-11-25
# 1          1002    Student_2  Female  Hyderabad      2024-09-29
# 2          1003    Student_3    Male       Pune      2024-12-05
# 3          1004    Student_4    Male      Delhi      2024-03-09
# 4          1005    Student_5    Male     Mumbai      2024-02-03
# ..          ...          ...     ...        ...             ...
# 495        1496  Student_496    Male  Hyderabad      2024-12-29
# 496        1497  Student_497    Male  Hyderabad      2024-10-06
# 497        1498  Student_498  Female  Bangalore      2024-03-21
# 498        1499  Student_499    Male     Mumbai      2024-07-20
# 499        1500  Student_500  Female       Pune      2024-06-06
#
#              course batch_type  total_sessions  sessions_attended  \
# 0     Generative AI    Weekday             120                108
# 1           AI & ML    Weekday             120                110
# 2      Data Science    Weekday             120                 73
# 3           AI & ML    Weekend             120                 71
# 4     Generative AI    Weekday             120                101
# ..              ...        ...             ...                ...
# 495    Data Science    Weekday             120                 86
# 496   Generative AI    Weekday             120                 61
# 497  Data Analytics    Weekday             120                 94
# 498    Data Science    Weekday             120                 77
# 499         AI & ML    Weekday             120                 73
#
#      avg_quiz_score  assignment_score  project_score  final_rating  \
# 0                59                96             66           3.7
# 1                57                93             83           4.5
# 2                49                72             73           3.6
# 3                64                91             81           2.7
# 4                41                55             50           2.1
# ..              ...               ...            ...           ...
# 495              94                97             57           3.1
# 496              88                53             72           3.7
# 497              94                53             63           3.4
# 498              72                48             76           NaN
# 499              57                79             78           3.8
#
#      learning_hours placement_status  feedback_score  attendance_pct  \
# 0                 6           Placed               7           90.00
# 1                33       Not Placed               8           91.67
# 2                 8           Placed               5           60.83
# 3                 5       Not Placed               8           59.17
# 4                23           Placed               9           84.17
# ..              ...              ...             ...             ...
# 495              14           Placed               7           71.67
# 496              28           Placed               5           50.83
# 497              39           Placed               7           78.33
# 498              27           Placed               8           64.17
# 499              21           Placed               7           60.83
#
#      salary_offered
# 0          738963.0
# 1               NaN
# 2          501904.0
# 3               NaN
# 4          970105.0
# ..              ...
# 495        572544.0
# 496        834633.0
# 497        333896.0
# 498        778646.0
# 499       1115331.0
#
# [500 rows x 18 columns]

# %%
df[:]
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 0          1001    Student_1    Male  Hyderabad      2024-11-25
# 1          1002    Student_2  Female  Hyderabad      2024-09-29
# 2          1003    Student_3    Male       Pune      2024-12-05
# 3          1004    Student_4    Male      Delhi      2024-03-09
# 4          1005    Student_5    Male     Mumbai      2024-02-03
# ..          ...          ...     ...        ...             ...
# 500        1452  Student_452  Female     Mumbai      2024-03-07
# 501        1276  Student_276  Female  Hyderabad      2024-10-15
# 502        1210  Student_210    Male  Bangalore      2024-04-04
# 503        1178  Student_178    Male      Delhi      2024-01-20
# 504        1397  Student_397  Female     Mumbai      2024-05-27
#
#             course batch_type  total_sessions  sessions_attended  \
# 0    Generative AI    Weekday             120                108
# 1          AI & ML    Weekday             120                110
# 2     Data Science    Weekday             120                 73
# 3          AI & ML    Weekend             120                 71
# 4    Generative AI    Weekday             120                101
# ..             ...        ...             ...                ...
# 500  Generative AI    Weekday             120                 68
# 501  Generative AI    Weekday             120                 95
# 502        AI & ML    Weekday             120                 75
# 503  Generative AI    Weekday             120                 80
# 504  Generative AI    Weekend             120                101
#
#      avg_quiz_score  assignment_score  project_score  final_rating  \
# 0                59                96             66           3.7
# 1                57                93             83           4.5
# 2                49                72             73           3.6
# 3                64                91             81           2.7
# 4                41                55             50           2.1
# ..              ...               ...            ...           ...
# 500              84                84             58           2.2
# 501              92                81             91           3.2
# 502              40                84             77           2.4
# 503              97                92             66           4.7
# 504              66                83             66           3.6
#
#      learning_hours placement_status  feedback_score  attendance_pct  \
# 0                 6           Placed               7           90.00
# 1                33       Not Placed               8           91.67
# 2                 8           Placed               5           60.83
# 3                 5       Not Placed               8           59.17
# 4                23           Placed               9           84.17
# ..              ...              ...             ...             ...
# 500              19       Not Placed               8           56.67
# 501              16       Not Placed               8           79.17
# 502              19           Placed               5           62.50
# 503              33           Placed               5           66.67
# 504              25           Placed               7           84.17
#
#      salary_offered
# 0          738963.0
# 1               NaN
# 2          501904.0
# 3               NaN
# 4          970105.0
# ..              ...
# 500             NaN
# 501             NaN
# 502        750043.0
# 503        890611.0
# 504       1003022.0
#
# [505 rows x 18 columns]

# %%
df['city'].nunique()
# Out:
# 6

# %%
df['course'].nunique()
# Out:
# 4

# %%
df['city'].unique
# Out:
# <bound method Series.unique of 0      Hyderabad
# 1      Hyderabad
# 2           Pune
# 3          Delhi
# 4         Mumbai
#          ...
# 500       Mumbai
# 501    Hyderabad
# 502    Bangalore
# 503        Delhi
# 504       Mumbai
# Name: city, Length: 505, dtype: object>

# %%
df['city'].value_counts()
# Out:
# city
# Hyderabad    100
# Mumbai        95
# Pune          87
# Bangalore     82
# Chennai       73
# Delhi         68
# Name: count, dtype: int64

# %%
df['course'].value_counts()
# Out:
# course
# Data Analytics    143
# Data Science      128
# AI & ML           126
# Generative AI     108
# Name: count, dtype: int64

# %%
df['course'].value_counts().head(1)
# Out:
# course
# Data Analytics    143
# Name: count, dtype: int64

# %%
df['placement_status'].value_counts()
# Out:
# placement_status
# Placed        336
# Not Placed    169
# Name: count, dtype: int64

# %%
df[df['attendance_pct']>80]
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 0          1001    Student_1    Male  Hyderabad      2024-11-25
# 1          1002    Student_2  Female  Hyderabad      2024-09-29
# 4          1005    Student_5    Male     Mumbai      2024-02-03
# 6          1007    Student_7    Male     Mumbai      2024-02-22
# 7          1008    Student_8    Male    Chennai      2024-07-23
# ..          ...          ...     ...        ...             ...
# 475        1476  Student_476  Female    Chennai      2024-02-05
# 477        1478  Student_478  Female     Mumbai      2024-07-06
# 481        1482  Student_482  Female     Mumbai      2024-07-15
# 488        1489  Student_489    Male    Chennai      2024-10-19
# 504        1397  Student_397  Female     Mumbai      2024-05-27
#
#              course batch_type  total_sessions  sessions_attended  \
# 0     Generative AI    Weekday             120                108
# 1           AI & ML    Weekday             120                110
# 4     Generative AI    Weekday             120                101
# 6    Data Analytics    Weekend             120                112
# 7      Data Science    Weekend             120                109
# ..              ...        ...             ...                ...
# 475  Data Analytics    Weekday             120                 97
# 477         AI & ML    Weekend             120                104
# 481   Generative AI    Weekend             120                101
# 488   Generative AI    Weekend             120                111
# 504   Generative AI    Weekend             120                101
#
#      avg_quiz_score  assignment_score  project_score  final_rating  \
# 0                59                96             66           3.7
# 1                57                93             83           4.5
# 4                41                55             50           2.1
# 6                93                89             94           3.2
# 7                72                77             72           4.3
# ..              ...               ...            ...           ...
# 475              99                99             94           3.6
# 477              88                73             87           3.8
# 481              63                56             66           3.6
# 488              70                49             75           3.3
# 504              66                83             66           3.6
#
#      learning_hours placement_status  feedback_score  attendance_pct  \
# 0                 6           Placed               7           90.00
# 1                33       Not Placed               8           91.67
# 4                23           Placed               9           84.17
# 6                29           Placed               6           93.33
# 7                14           Placed               6           90.83
# ..              ...              ...             ...             ...
# 475              33           Placed               9           80.83
# 477              14           Placed               5           86.67
# 481              30           Placed               9           84.17
# 488              26       Not Placed               7           92.50
# 504              25           Placed               7           84.17
#
#      salary_offered
# 0          738963.0
# 1               NaN
# 4          970105.0
# 6          707137.0
# 7         1053790.0
# ..              ...
# 475        855839.0
# 477        749813.0
# 481        309637.0
# 488             NaN
# 504       1003022.0
#
# [181 rows x 18 columns]

# %%
df[df['attendance_pct']<70]
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 2          1003    Student_3    Male       Pune      2024-12-05
# 3          1004    Student_4    Male      Delhi      2024-03-09
# 5          1006    Student_6  Female       Pune      2024-09-18
# 8          1009    Student_9    Male     Mumbai      2024-05-05
# 22         1023   Student_23  Female    Chennai      2024-07-13
# ..          ...          ...     ...        ...             ...
# 498        1499  Student_499    Male     Mumbai      2024-07-20
# 499        1500  Student_500  Female       Pune      2024-06-06
# 500        1452  Student_452  Female     Mumbai      2024-03-07
# 502        1210  Student_210    Male  Bangalore      2024-04-04
# 503        1178  Student_178    Male      Delhi      2024-01-20
#
#             course batch_type  total_sessions  sessions_attended  \
# 2     Data Science    Weekday             120                 73
# 3          AI & ML    Weekend             120                 71
# 5    Generative AI    Weekend             120                 79
# 8          AI & ML    Weekend             120                 83
# 22   Generative AI    Weekend             120                 82
# ..             ...        ...             ...                ...
# 498   Data Science    Weekday             120                 77
# 499        AI & ML    Weekday             120                 73
# 500  Generative AI    Weekday             120                 68
# 502        AI & ML    Weekday             120                 75
# 503  Generative AI    Weekday             120                 80
#
#      avg_quiz_score  assignment_score  project_score  final_rating  \
# 2                49                72             73           3.6
# 3                64                91             81           2.7
# 5                64                98             57           2.6
# 8                75                61             96           2.6
# 22               52                70             87           4.8
# ..              ...               ...            ...           ...
# 498              72                48             76           NaN
# 499              57                79             78           3.8
# 500              84                84             58           2.2
# 502              40                84             77           2.4
# 503              97                92             66           4.7
#
#      learning_hours placement_status  feedback_score  attendance_pct  \
# 2                 8           Placed               5           60.83
# 3                 5       Not Placed               8           59.17
# 5                30           Placed               6           65.83
# 8                19           Placed               8           69.17
# 22               14       Not Placed               5           68.33
# ..              ...              ...             ...             ...
# 498              27           Placed               8           64.17
# 499              21           Placed               7           60.83
# 500              19       Not Placed               8           56.67
# 502              19           Placed               5           62.50
# 503              33           Placed               5           66.67
#
#      salary_offered
# 2          501904.0
# 3               NaN
# 5          305730.0
# 8          502210.0
# 22              NaN
# ..              ...
# 498        778646.0
# 499       1115331.0
# 500             NaN
# 502        750043.0
# 503        890611.0
#
# [219 rows x 18 columns]

# %%
df[df['attendance_pct']>85]
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 0          1001    Student_1    Male  Hyderabad      2024-11-25
# 1          1002    Student_2  Female  Hyderabad      2024-09-29
# 6          1007    Student_7    Male     Mumbai      2024-02-22
# 7          1008    Student_8    Male    Chennai      2024-07-23
# 9          1010   Student_10  Female      Delhi      2024-08-22
# ..          ...          ...     ...        ...             ...
# 469        1470  Student_470  Female  Hyderabad      2024-09-19
# 472        1473  Student_473    Male     Mumbai      2024-03-25
# 473        1474  Student_474  Female      Delhi      2024-05-26
# 477        1478  Student_478  Female     Mumbai      2024-07-06
# 488        1489  Student_489    Male    Chennai      2024-10-19
#
#              course batch_type  total_sessions  sessions_attended  \
# 0     Generative AI    Weekday             120                108
# 1           AI & ML    Weekday             120                110
# 6    Data Analytics    Weekend             120                112
# 7      Data Science    Weekend             120                109
# 9    Data Analytics    Weekday             120                118
# ..              ...        ...             ...                ...
# 469   Generative AI    Weekday             120                111
# 472         AI & ML    Weekend             120                106
# 473  Data Analytics    Weekend             120                108
# 477         AI & ML    Weekend             120                104
# 488   Generative AI    Weekend             120                111
#
#      avg_quiz_score  assignment_score  project_score  final_rating  \
# 0                59                96             66           3.7
# 1                57                93             83           4.5
# 6                93                89             94           3.2
# 7                72                77             72           4.3
# 9                70                50             89           4.2
# ..              ...               ...            ...           ...
# 469              73                52             52           3.6
# 472              58                90             94           2.6
# 473              70                66             81           3.7
# 477              88                73             87           3.8
# 488              70                49             75           3.3
#
#      learning_hours placement_status  feedback_score  attendance_pct  \
# 0                 6           Placed               7           90.00
# 1                33       Not Placed               8           91.67
# 6                29           Placed               6           93.33
# 7                14           Placed               6           90.83
# 9                26       Not Placed               8           98.33
# ..              ...              ...             ...             ...
# 469              24       Not Placed               6           92.50
# 472              27           Placed               9           88.33
# 473              15       Not Placed               6           90.00
# 477              14           Placed               5           86.67
# 488              26       Not Placed               7           92.50
#
#      salary_offered
# 0          738963.0
# 1               NaN
# 6          707137.0
# 7         1053790.0
# 9               NaN
# ..              ...
# 469             NaN
# 472        783178.0
# 473             NaN
# 477        749813.0
# 488             NaN
#
# [131 rows x 18 columns]

# %%
df[df['course']=='Data Science']
# Out:
#      student_id student_name  gender       city enrollment_date        course  \
# 2          1003    Student_3    Male       Pune      2024-12-05  Data Science
# 7          1008    Student_8    Male    Chennai      2024-07-23  Data Science
# 10         1011   Student_11    Male    Chennai      2024-02-12  Data Science
# 13         1014   Student_14    Male     Mumbai      2024-09-05  Data Science
# 18         1019   Student_19  Female       Pune      2024-01-08  Data Science
# ..          ...          ...     ...        ...             ...           ...
# 487        1488  Student_488  Female       Pune      2024-09-17  Data Science
# 489        1490  Student_490    Male       Pune      2024-09-12  Data Science
# 490        1491  Student_491  Female  Bangalore      2024-08-09  Data Science
# 495        1496  Student_496    Male  Hyderabad      2024-12-29  Data Science
# 498        1499  Student_499    Male     Mumbai      2024-07-20  Data Science
#
#     batch_type  total_sessions  sessions_attended  avg_quiz_score  \
# 2      Weekday             120                 73              49
# 7      Weekend             120                109              72
# 10     Weekday             120                102              53
# 13     Weekday             120                109              55
# 18     Weekend             120                115              74
# ..         ...             ...                ...             ...
# 487    Weekday             120                 66              92
# 489    Weekend             120                 73              75
# 490    Weekday             120                 68              58
# 495    Weekday             120                 86              94
# 498    Weekday             120                 77              72
#
#      assignment_score  project_score  final_rating  learning_hours  \
# 2                  72             73           3.6               8
# 7                  77             72           4.3              14
# 10                 48             61           4.6              25
# 13                 91             96           3.7              34
# 18                 58             78           2.9              11
# ..                ...            ...           ...             ...
# 487                65             51           2.2              27
# 489                92             62           4.1               6
# 490                64             96           3.4              35
# 495                97             57           3.1              14
# 498                48             76           NaN              27
#
#     placement_status  feedback_score  attendance_pct  salary_offered
# 2             Placed               5           60.83        501904.0
# 7             Placed               6           90.83       1053790.0
# 10        Not Placed               7           85.00             NaN
# 13            Placed               6           90.83        645430.0
# 18            Placed               8           95.83       1000399.0
# ..               ...             ...             ...             ...
# 487           Placed               7           55.00        797760.0
# 489           Placed               7           60.83        667747.0
# 490           Placed               6           56.67       1097955.0
# 495           Placed               7           71.67        572544.0
# 498           Placed               8           64.17        778646.0
#
# [128 rows x 18 columns]

# %%
df[(df['placement_status']=='Not Placed') & (df['sessions_attended']>75)]
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 1          1002    Student_2  Female  Hyderabad      2024-09-29
# 9          1010   Student_10  Female      Delhi      2024-08-22
# 10         1011   Student_11    Male    Chennai      2024-02-12
# 15         1016   Student_16    Male     Mumbai      2024-07-01
# 16         1017   Student_17  Female     Mumbai      2024-12-01
# ..          ...          ...     ...        ...             ...
# 469        1470  Student_470  Female  Hyderabad      2024-09-19
# 473        1474  Student_474  Female      Delhi      2024-05-26
# 480        1481  Student_481  Female     Mumbai      2024-10-29
# 488        1489  Student_489    Male    Chennai      2024-10-19
# 501        1276  Student_276  Female  Hyderabad      2024-10-15
#
#              course batch_type  total_sessions  sessions_attended  \
# 1           AI & ML    Weekday             120                110
# 9    Data Analytics    Weekday             120                118
# 10     Data Science    Weekday             120                102
# 15   Data Analytics    Weekday             120                116
# 16          AI & ML    Weekend             120                 98
# ..              ...        ...             ...                ...
# 469   Generative AI    Weekday             120                111
# 473  Data Analytics    Weekend             120                108
# 480    Data Science    Weekday             120                 83
# 488   Generative AI    Weekend             120                111
# 501   Generative AI    Weekday             120                 95
#
#      avg_quiz_score  assignment_score  project_score  final_rating  \
# 1                57                93             83           4.5
# 9                70                50             89           4.2
# 10               53                48             61           4.6
# 15               85                59             90           3.6
# 16               91                50             68           3.4
# ..              ...               ...            ...           ...
# 469              73                52             52           3.6
# 473              70                66             81           3.7
# 480              61                74             89           3.9
# 488              70                49             75           3.3
# 501              92                81             91           3.2
#
#      learning_hours placement_status  feedback_score  attendance_pct  \
# 1                33       Not Placed               8           91.67
# 9                26       Not Placed               8           98.33
# 10               25       Not Placed               7           85.00
# 15               32       Not Placed               7           96.67
# 16                5       Not Placed               9           81.67
# ..              ...              ...             ...             ...
# 469              24       Not Placed               6           92.50
# 473              15       Not Placed               6           90.00
# 480              36       Not Placed               7           69.17
# 488              26       Not Placed               7           92.50
# 501              16       Not Placed               8           79.17
#
#      salary_offered
# 1               NaN
# 9               NaN
# 10              NaN
# 15              NaN
# 16              NaN
# ..              ...
# 469             NaN
# 473             NaN
# 480             NaN
# 488             NaN
# 501             NaN
#
# [119 rows x 18 columns]

# %%
df[df['city'].isin(['Pune','Bangalore','Hyderabad'])]
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 0          1001    Student_1    Male  Hyderabad      2024-11-25
# 1          1002    Student_2  Female  Hyderabad      2024-09-29
# 2          1003    Student_3    Male       Pune      2024-12-05
# 5          1006    Student_6  Female       Pune      2024-09-18
# 18         1019   Student_19  Female       Pune      2024-01-08
# ..          ...          ...     ...        ...             ...
# 496        1497  Student_497    Male  Hyderabad      2024-10-06
# 497        1498  Student_498  Female  Bangalore      2024-03-21
# 499        1500  Student_500  Female       Pune      2024-06-06
# 501        1276  Student_276  Female  Hyderabad      2024-10-15
# 502        1210  Student_210    Male  Bangalore      2024-04-04
#
#              course batch_type  total_sessions  sessions_attended  \
# 0     Generative AI    Weekday             120                108
# 1           AI & ML    Weekday             120                110
# 2      Data Science    Weekday             120                 73
# 5     Generative AI    Weekend             120                 79
# 18     Data Science    Weekend             120                115
# ..              ...        ...             ...                ...
# 496   Generative AI    Weekday             120                 61
# 497  Data Analytics    Weekday             120                 94
# 499         AI & ML    Weekday             120                 73
# 501   Generative AI    Weekday             120                 95
# 502         AI & ML    Weekday             120                 75
#
#      avg_quiz_score  assignment_score  project_score  final_rating  \
# 0                59                96             66           3.7
# 1                57                93             83           4.5
# 2                49                72             73           3.6
# 5                64                98             57           2.6
# 18               74                58             78           2.9
# ..              ...               ...            ...           ...
# 496              88                53             72           3.7
# 497              94                53             63           3.4
# 499              57                79             78           3.8
# 501              92                81             91           3.2
# 502              40                84             77           2.4
#
#      learning_hours placement_status  feedback_score  attendance_pct  \
# 0                 6           Placed               7           90.00
# 1                33       Not Placed               8           91.67
# 2                 8           Placed               5           60.83
# 5                30           Placed               6           65.83
# 18               11           Placed               8           95.83
# ..              ...              ...             ...             ...
# 496              28           Placed               5           50.83
# 497              39           Placed               7           78.33
# 499              21           Placed               7           60.83
# 501              16       Not Placed               8           79.17
# 502              19           Placed               5           62.50
#
#      salary_offered
# 0          738963.0
# 1               NaN
# 2          501904.0
# 5          305730.0
# 18        1000399.0
# ..              ...
# 496        834633.0
# 497        333896.0
# 499       1115331.0
# 501             NaN
# 502        750043.0
#
# [269 rows x 18 columns]

# %%
df[df['course'].isin(['AI & ML','Generative AI'])]
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 0          1001    Student_1    Male  Hyderabad      2024-11-25
# 1          1002    Student_2  Female  Hyderabad      2024-09-29
# 3          1004    Student_4    Male      Delhi      2024-03-09
# 4          1005    Student_5    Male     Mumbai      2024-02-03
# 5          1006    Student_6  Female       Pune      2024-09-18
# ..          ...          ...     ...        ...             ...
# 500        1452  Student_452  Female     Mumbai      2024-03-07
# 501        1276  Student_276  Female  Hyderabad      2024-10-15
# 502        1210  Student_210    Male  Bangalore      2024-04-04
# 503        1178  Student_178    Male      Delhi      2024-01-20
# 504        1397  Student_397  Female     Mumbai      2024-05-27
#
#             course batch_type  total_sessions  sessions_attended  \
# 0    Generative AI    Weekday             120                108
# 1          AI & ML    Weekday             120                110
# 3          AI & ML    Weekend             120                 71
# 4    Generative AI    Weekday             120                101
# 5    Generative AI    Weekend             120                 79
# ..             ...        ...             ...                ...
# 500  Generative AI    Weekday             120                 68
# 501  Generative AI    Weekday             120                 95
# 502        AI & ML    Weekday             120                 75
# 503  Generative AI    Weekday             120                 80
# 504  Generative AI    Weekend             120                101
#
#      avg_quiz_score  assignment_score  project_score  final_rating  \
# 0                59                96             66           3.7
# 1                57                93             83           4.5
# 3                64                91             81           2.7
# 4                41                55             50           2.1
# 5                64                98             57           2.6
# ..              ...               ...            ...           ...
# 500              84                84             58           2.2
# 501              92                81             91           3.2
# 502              40                84             77           2.4
# 503              97                92             66           4.7
# 504              66                83             66           3.6
#
#      learning_hours placement_status  feedback_score  attendance_pct  \
# 0                 6           Placed               7           90.00
# 1                33       Not Placed               8           91.67
# 3                 5       Not Placed               8           59.17
# 4                23           Placed               9           84.17
# 5                30           Placed               6           65.83
# ..              ...              ...             ...             ...
# 500              19       Not Placed               8           56.67
# 501              16       Not Placed               8           79.17
# 502              19           Placed               5           62.50
# 503              33           Placed               5           66.67
# 504              25           Placed               7           84.17
#
#      salary_offered
# 0          738963.0
# 1               NaN
# 3               NaN
# 4          970105.0
# 5          305730.0
# ..              ...
# 500             NaN
# 501             NaN
# 502        750043.0
# 503        890611.0
# 504       1003022.0
#
# [234 rows x 18 columns]

# %%
df[df['avg_quiz_score'].between(60,80)]
# Out:
#      student_id student_name  gender     city enrollment_date          course  \
# 3          1004    Student_4    Male    Delhi      2024-03-09         AI & ML
# 5          1006    Student_6  Female     Pune      2024-09-18   Generative AI
# 7          1008    Student_8    Male  Chennai      2024-07-23    Data Science
# 8          1009    Student_9    Male   Mumbai      2024-05-05         AI & ML
# 9          1010   Student_10  Female    Delhi      2024-08-22  Data Analytics
# ..          ...          ...     ...      ...             ...             ...
# 489        1490  Student_490    Male     Pune      2024-09-12    Data Science
# 493        1494  Student_494  Female    Delhi      2024-12-20   Generative AI
# 494        1495  Student_495    Male     Pune      2024-12-07         AI & ML
# 498        1499  Student_499    Male   Mumbai      2024-07-20    Data Science
# 504        1397  Student_397  Female   Mumbai      2024-05-27   Generative AI
#
#     batch_type  total_sessions  sessions_attended  avg_quiz_score  \
# 3      Weekend             120                 71              64
# 5      Weekend             120                 79              64
# 7      Weekend             120                109              72
# 8      Weekend             120                 83              75
# 9      Weekday             120                118              70
# ..         ...             ...                ...             ...
# 489    Weekend             120                 73              75
# 493    Weekday             120                 94              75
# 494    Weekend             120                 61              69
# 498    Weekday             120                 77              72
# 504    Weekend             120                101              66
#
#      assignment_score  project_score  final_rating  learning_hours  \
# 3                  91             81           2.7               5
# 5                  98             57           2.6              30
# 7                  77             72           4.3              14
# 8                  61             96           2.6              19
# 9                  50             89           4.2              26
# ..                ...            ...           ...             ...
# 489                92             62           4.1               6
# 493                88             88           3.9              36
# 494                77             52           4.1               9
# 498                48             76           NaN              27
# 504                83             66           3.6              25
#
#     placement_status  feedback_score  attendance_pct  salary_offered
# 3         Not Placed               8           59.17             NaN
# 5             Placed               6           65.83        305730.0
# 7             Placed               6           90.83       1053790.0
# 8             Placed               8           69.17        502210.0
# 9         Not Placed               8           98.33             NaN
# ..               ...             ...             ...             ...
# 489           Placed               7           60.83        667747.0
# 493           Placed               8           78.33        596618.0
# 494           Placed               8           50.83        867354.0
# 498           Placed               8           64.17        778646.0
# 504           Placed               7           84.17       1003022.0
#
# [194 rows x 18 columns]

# %%
df[df['assignment_score'].between(70,90)]
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 2          1003    Student_3    Male       Pune      2024-12-05
# 6          1007    Student_7    Male     Mumbai      2024-02-22
# 7          1008    Student_8    Male    Chennai      2024-07-23
# 14         1015   Student_15  Female      Delhi      2024-05-30
# 20         1021   Student_21  Female       Pune      2024-07-02
# ..          ...          ...     ...        ...             ...
# 499        1500  Student_500  Female       Pune      2024-06-06
# 500        1452  Student_452  Female     Mumbai      2024-03-07
# 501        1276  Student_276  Female  Hyderabad      2024-10-15
# 502        1210  Student_210    Male  Bangalore      2024-04-04
# 504        1397  Student_397  Female     Mumbai      2024-05-27
#
#              course batch_type  total_sessions  sessions_attended  \
# 2      Data Science    Weekday             120                 73
# 6    Data Analytics    Weekend             120                112
# 7      Data Science    Weekend             120                109
# 14   Data Analytics    Weekend             120                 88
# 20          AI & ML    Weekday             120                102
# ..              ...        ...             ...                ...
# 499         AI & ML    Weekday             120                 73
# 500   Generative AI    Weekday             120                 68
# 501   Generative AI    Weekday             120                 95
# 502         AI & ML    Weekday             120                 75
# 504   Generative AI    Weekend             120                101
#
#      avg_quiz_score  assignment_score  project_score  final_rating  \
# 2                49                72             73           3.6
# 6                93                89             94           3.2
# 7                72                77             72           4.3
# 14               93                71             64           3.9
# 20               45                83             89           3.7
# ..              ...               ...            ...           ...
# 499              57                79             78           3.8
# 500              84                84             58           2.2
# 501              92                81             91           3.2
# 502              40                84             77           2.4
# 504              66                83             66           3.6
#
#      learning_hours placement_status  feedback_score  attendance_pct  \
# 2                 8           Placed               5           60.83
# 6                29           Placed               6           93.33
# 7                14           Placed               6           90.83
# 14               29           Placed               7           73.33
# 20               23       Not Placed               6           85.00
# ..              ...              ...             ...             ...
# 499              21           Placed               7           60.83
# 500              19       Not Placed               8           56.67
# 501              16       Not Placed               8           79.17
# 502              19           Placed               5           62.50
# 504              25           Placed               7           84.17
#
#      salary_offered
# 2          501904.0
# 6          707137.0
# 7         1053790.0
# 14        1128411.0
# 20              NaN
# ..              ...
# 499       1115331.0
# 500             NaN
# 501             NaN
# 502        750043.0
# 504       1003022.0
#
# [189 rows x 18 columns]

# %%
df[df['learning_hours'].between(10,25)]
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 4          1005    Student_5    Male     Mumbai      2024-02-03
# 7          1008    Student_8    Male    Chennai      2024-07-23
# 8          1009    Student_9    Male     Mumbai      2024-05-05
# 10         1011   Student_11    Male    Chennai      2024-02-12
# 18         1019   Student_19  Female       Pune      2024-01-08
# ..          ...          ...     ...        ...             ...
# 499        1500  Student_500  Female       Pune      2024-06-06
# 500        1452  Student_452  Female     Mumbai      2024-03-07
# 501        1276  Student_276  Female  Hyderabad      2024-10-15
# 502        1210  Student_210    Male  Bangalore      2024-04-04
# 504        1397  Student_397  Female     Mumbai      2024-05-27
#
#             course batch_type  total_sessions  sessions_attended  \
# 4    Generative AI    Weekday             120                101
# 7     Data Science    Weekend             120                109
# 8          AI & ML    Weekend             120                 83
# 10    Data Science    Weekday             120                102
# 18    Data Science    Weekend             120                115
# ..             ...        ...             ...                ...
# 499        AI & ML    Weekday             120                 73
# 500  Generative AI    Weekday             120                 68
# 501  Generative AI    Weekday             120                 95
# 502        AI & ML    Weekday             120                 75
# 504  Generative AI    Weekend             120                101
#
#      avg_quiz_score  assignment_score  project_score  final_rating  \
# 4                41                55             50           2.1
# 7                72                77             72           4.3
# 8                75                61             96           2.6
# 10               53                48             61           4.6
# 18               74                58             78           2.9
# ..              ...               ...            ...           ...
# 499              57                79             78           3.8
# 500              84                84             58           2.2
# 501              92                81             91           3.2
# 502              40                84             77           2.4
# 504              66                83             66           3.6
#
#      learning_hours placement_status  feedback_score  attendance_pct  \
# 4                23           Placed               9           84.17
# 7                14           Placed               6           90.83
# 8                19           Placed               8           69.17
# 10               25       Not Placed               7           85.00
# 18               11           Placed               8           95.83
# ..              ...              ...             ...             ...
# 499              21           Placed               7           60.83
# 500              19       Not Placed               8           56.67
# 501              16       Not Placed               8           79.17
# 502              19           Placed               5           62.50
# 504              25           Placed               7           84.17
#
#      salary_offered
# 4          970105.0
# 7         1053790.0
# 8          502210.0
# 10              NaN
# 18        1000399.0
# ..              ...
# 499       1115331.0
# 500             NaN
# 501             NaN
# 502        750043.0
# 504       1003022.0
#
# [228 rows x 18 columns]

# %%
df['learning_hours'].value_counts()
# Out:
# learning_hours
# 19    22
# 36    22
# 33    21
# 32    20
# 26    19
# 15    19
# 34    18
# 7     18
# 14    17
# 21    16
# 27    16
# 24    16
# 23    16
# 25    16
# 5     15
# 17    14
# 6     14
# 13    14
# 29    14
# 8     13
# 16    13
# 11    12
# 30    12
# 12    12
# 20    12
# 9     12
# 22    12
# 28    11
# 31    11
# 39    11
# 38    10
# 35    10
# 37    10
# 10     9
# 18     8
# Name: count, dtype: int64

# %%
(df['placement_status']=='Eligible').mean()*100
# Out:
# np.float64(0.0)

# %%
df[df['placement_status']=='Placed']['city'].value_counts().head(1)
# Out:
# city
# Hyderabad    69
# Name: count, dtype: int64

# %%
df.sort_values('attendance_pct',ascending=False).head(5)
# Out:
#      student_id student_name  gender    city enrollment_date          course  \
# 467        1468  Student_468    Male    Pune      2024-01-07         AI & ML
# 32         1033   Student_33  Female    Pune      2024-01-05    Data Science
# 326        1327  Student_327    Male    Pune      2024-04-13    Data Science
# 276        1277  Student_277    Male  Mumbai      2024-09-10  Data Analytics
# 355        1356  Student_356    Male   Delhi      2024-11-14   Generative AI
#
#     batch_type  total_sessions  sessions_attended  avg_quiz_score  \
# 467    Weekend             120                119              95
# 32     Weekend             120                119              84
# 326    Weekday             120                119              85
# 276    Weekday             120                119              71
# 355    Weekend             120                119              83
#
#      assignment_score  project_score  final_rating  learning_hours  \
# 467                48             84           4.9              36
# 32                 74             94           2.6              29
# 326                88             60           4.8              17
# 276                48             86           3.7              14
# 355                61             54           2.7              28
#
#     placement_status  feedback_score  attendance_pct  salary_offered
# 467           Placed               8           99.17        903623.0
# 32        Not Placed               8           99.17             NaN
# 326           Placed               6           99.17       1053375.0
# 276           Placed               5           99.17        649173.0
# 355       Not Placed               6           99.17             NaN
